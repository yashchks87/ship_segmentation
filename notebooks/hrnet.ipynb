# %%
import tensorflow as tf
from tensorflow import keras
import tensorflow.keras.backend as K
# Out:
# 2023-05-16 19:00:29.303227: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-16 19:00:29.649254: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-05-16 19:00:30.565136: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-05-16 19:00:30.565206: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-05-16 19:00:30.565215: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
import keras.backend as K
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization, Activation
from keras.layers import UpSampling2D, add, concatenate


def conv3x3(x, out_filters, strides=(1, 1)):
    x = Conv2D(out_filters, 3, padding='same', strides=strides, use_bias=False, kernel_initializer='he_normal')(x)
    return x


def basic_Block(input, out_filters, strides=(1, 1), with_conv_shortcut=False):
    x = conv3x3(input, out_filters, strides)
    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)

    x = conv3x3(x, out_filters)
    x = BatchNormalization(axis=3)(x)

    if with_conv_shortcut:
        residual = Conv2D(out_filters, 1, strides=strides, use_bias=False, kernel_initializer='he_normal')(input)
        residual = BatchNormalization(axis=3)(residual)
        x = add([x, residual])
    else:
        x = add([x, input])

    x = Activation('relu')(x)
    return x


def bottleneck_Block(input, out_filters, strides=(1, 1), with_conv_shortcut=False):
    expansion = 4
    de_filters = int(out_filters / expansion)

    x = Conv2D(de_filters, 1, use_bias=False, kernel_initializer='he_normal')(input)
    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)

    x = Conv2D(de_filters, 3, strides=strides, padding='same', use_bias=False, kernel_initializer='he_normal')(x)
    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)

    x = Conv2D(out_filters, 1, use_bias=False, kernel_initializer='he_normal')(x)
    x = BatchNormalization(axis=3)(x)

    if with_conv_shortcut:
        residual = Conv2D(out_filters, 1, strides=strides, use_bias=False, kernel_initializer='he_normal')(input)
        residual = BatchNormalization(axis=3)(residual)
        x = add([x, residual])
    else:
        x = add([x, input])

    x = Activation('relu')(x)
    return x


def stem_net(input):
    x = Conv2D(64, 3, strides=(2, 2), padding='same', use_bias=False, kernel_initializer='he_normal')(input)
    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)

    # x = Conv2D(64, 3, strides=(2, 2), padding='same', use_bias=False, kernel_initializer='he_normal')(x)
    # x = BatchNormalization(axis=3)(x)
    # x = Activation('relu')(x)

    x = bottleneck_Block(x, 256, with_conv_shortcut=True)
    x = bottleneck_Block(x, 256, with_conv_shortcut=False)
    x = bottleneck_Block(x, 256, with_conv_shortcut=False)
    x = bottleneck_Block(x, 256, with_conv_shortcut=False)

    return x


def transition_layer1(x, out_filters_list=[32, 64]):
    x0 = Conv2D(out_filters_list[0], 3, padding='same', use_bias=False, kernel_initializer='he_normal')(x)
    x0 = BatchNormalization(axis=3)(x0)
    x0 = Activation('relu')(x0)

    x1 = Conv2D(out_filters_list[1], 3, strides=(2, 2),
                padding='same', use_bias=False, kernel_initializer='he_normal')(x)
    x1 = BatchNormalization(axis=3)(x1)
    x1 = Activation('relu')(x1)

    return [x0, x1]


def make_branch1_0(x, out_filters=32):
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    return x


def make_branch1_1(x, out_filters=64):
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    return x


def fuse_layer1(x):
    x0_0 = x[0]
    x0_1 = Conv2D(32, 1, use_bias=False, kernel_initializer='he_normal')(x[1])
    x0_1 = BatchNormalization(axis=3)(x0_1)
    x0_1 = UpSampling2D(size=(2, 2))(x0_1)
    x0 = add([x0_0, x0_1])

    x1_0 = Conv2D(64, 3, strides=(2, 2), padding='same', use_bias=False, kernel_initializer='he_normal')(x[0])
    x1_0 = BatchNormalization(axis=3)(x1_0)
    x1_1 = x[1]
    x1 = add([x1_0, x1_1])
    return [x0, x1]


def transition_layer2(x, out_filters_list=[32, 64, 128]):
    x0 = Conv2D(out_filters_list[0], 3, padding='same', use_bias=False, kernel_initializer='he_normal')(x[0])
    x0 = BatchNormalization(axis=3)(x0)
    x0 = Activation('relu')(x0)

    x1 = Conv2D(out_filters_list[1], 3, padding='same', use_bias=False, kernel_initializer='he_normal')(x[1])
    x1 = BatchNormalization(axis=3)(x1)
    x1 = Activation('relu')(x1)

    x2 = Conv2D(out_filters_list[2], 3, strides=(2, 2),
                padding='same', use_bias=False, kernel_initializer='he_normal')(x[1])
    x2 = BatchNormalization(axis=3)(x2)
    x2 = Activation('relu')(x2)

    return [x0, x1, x2]


def make_branch2_0(x, out_filters=32):
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    return x


def make_branch2_1(x, out_filters=64):
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    return x


def make_branch2_2(x, out_filters=128):
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    return x


def fuse_layer2(x):
    x0_0 = x[0]
    x0_1 = Conv2D(32, 1, use_bias=False, kernel_initializer='he_normal')(x[1])
    x0_1 = BatchNormalization(axis=3)(x0_1)
    x0_1 = UpSampling2D(size=(2, 2))(x0_1)
    x0_2 = Conv2D(32, 1, use_bias=False, kernel_initializer='he_normal')(x[2])
    x0_2 = BatchNormalization(axis=3)(x0_2)
    x0_2 = UpSampling2D(size=(4, 4))(x0_2)
    x0 = add([x0_0, x0_1, x0_2])

    x1_0 = Conv2D(64, 3, strides=(2, 2), padding='same', use_bias=False, kernel_initializer='he_normal')(x[0])
    x1_0 = BatchNormalization(axis=3)(x1_0)
    x1_1 = x[1]
    x1_2 = Conv2D(64, 1, use_bias=False, kernel_initializer='he_normal')(x[2])
    x1_2 = BatchNormalization(axis=3)(x1_2)
    x1_2 = UpSampling2D(size=(2, 2))(x1_2)
    x1 = add([x1_0, x1_1, x1_2])

    x2_0 = Conv2D(32, 3, strides=(2, 2), padding='same', use_bias=False, kernel_initializer='he_normal')(x[0])
    x2_0 = BatchNormalization(axis=3)(x2_0)
    x2_0 = Activation('relu')(x2_0)
    x2_0 = Conv2D(128, 3, strides=(2, 2), padding='same', use_bias=False, kernel_initializer='he_normal')(x2_0)
    x2_0 = BatchNormalization(axis=3)(x2_0)
    x2_1 = Conv2D(128, 3, strides=(2, 2), padding='same', use_bias=False, kernel_initializer='he_normal')(x[1])
    x2_1 = BatchNormalization(axis=3)(x2_1)
    x2_2 = x[2]
    x2 = add([x2_0, x2_1, x2_2])
    return [x0, x1, x2]


def transition_layer3(x, out_filters_list=[32, 64, 128, 256]):
    x0 = Conv2D(out_filters_list[0], 3, padding='same', use_bias=False, kernel_initializer='he_normal')(x[0])
    x0 = BatchNormalization(axis=3)(x0)
    x0 = Activation('relu')(x0)

    x1 = Conv2D(out_filters_list[1], 3, padding='same', use_bias=False, kernel_initializer='he_normal')(x[1])
    x1 = BatchNormalization(axis=3)(x1)
    x1 = Activation('relu')(x1)

    x2 = Conv2D(out_filters_list[2], 3, padding='same', use_bias=False, kernel_initializer='he_normal')(x[2])
    x2 = BatchNormalization(axis=3)(x2)
    x2 = Activation('relu')(x2)

    x3 = Conv2D(out_filters_list[3], 3, strides=(2, 2),
                padding='same', use_bias=False, kernel_initializer='he_normal')(x[2])
    x3 = BatchNormalization(axis=3)(x3)
    x3 = Activation('relu')(x3)

    return [x0, x1, x2, x3]


def make_branch3_0(x, out_filters=32):
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    return x


def make_branch3_1(x, out_filters=64):
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    return x


def make_branch3_2(x, out_filters=128):
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    return x


def make_branch3_3(x, out_filters=256):
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    x = basic_Block(x, out_filters, with_conv_shortcut=False)
    return x


def fuse_layer3(x):
    x0_0 = x[0]
    x0_1 = Conv2D(32, 1, use_bias=False, kernel_initializer='he_normal')(x[1])
    x0_1 = BatchNormalization(axis=3)(x0_1)
    x0_1 = UpSampling2D(size=(2, 2))(x0_1)
    x0_2 = Conv2D(32, 1, use_bias=False, kernel_initializer='he_normal')(x[2])
    x0_2 = BatchNormalization(axis=3)(x0_2)
    x0_2 = UpSampling2D(size=(4, 4))(x0_2)
    x0_3 = Conv2D(32, 1, use_bias=False, kernel_initializer='he_normal')(x[3])
    x0_3 = BatchNormalization(axis=3)(x0_3)
    x0_3 = UpSampling2D(size=(8, 8))(x0_3)
    x0 = concatenate([x0_0, x0_1, x0_2, x0_3], axis=-1)
    return x0


def final_layer(x, classes=1):
    x = UpSampling2D(size=(2, 2))(x)
    x = Conv2D(classes, 1, use_bias=False, kernel_initializer='he_normal')(x)
    x = BatchNormalization(axis=3)(x)
    x = Activation('sigmoid', name='Classification')(x)
    return x


def seg_hrnet(batch_size, height, width, channel, classes):
    inputs = Input(batch_shape=(batch_size,) + (height, width, channel))

    x = stem_net(inputs)

    x = transition_layer1(x)
    x0 = make_branch1_0(x[0])
    x1 = make_branch1_1(x[1])
    x = fuse_layer1([x0, x1])

    x = transition_layer2(x)
    x0 = make_branch2_0(x[0])
    x1 = make_branch2_1(x[1])
    x2 = make_branch2_2(x[2])
    x = fuse_layer2([x0, x1, x2])

    x = transition_layer3(x)
    x0 = make_branch3_0(x[0])
    x1 = make_branch3_1(x[1])
    x2 = make_branch3_2(x[2])
    x3 = make_branch3_3(x[3])
    x = fuse_layer3([x0, x1, x2, x3])

    out = final_layer(x, classes=classes)

    model = Model(inputs=inputs, outputs=out)

    return model

# %%
hrnet = seg_hrnet(32, 256, 256, 3, 2)
# Out:
# 2023-05-16 19:01:37.978923: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:37.979674: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:37.996685: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:37.997449: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:37.998140: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:37.998833: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:37.999539: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:38.000265: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:38.043518: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:38.060492: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:38.065183: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:38.065852: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:38.066525: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:38.067167: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:38.067811: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:38.068491: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:38.069143: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:38.069789: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:38.070435: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:38.071074: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:38.071711: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:38.072405: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:38.073045: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:38.073687: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:38.088750: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-16 19:01:40.828331: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:40.829025: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:40.829655: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:40.830284: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:40.830899: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:40.831535: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:40.832151: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:40.832802: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:40.833466: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:40.834088: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:40.834710: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:40.835750: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:40.837253: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:40.838583: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:40.839925: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:40.841297: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:40.842637: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:40.844020: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:40.845320: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:40.845955: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:40.846605: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:40.847239: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:40.847848: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:40.848551: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.096091: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.096936: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.097643: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.098319: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.098999: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.099887: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.101258: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.107142: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.112179: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.112908: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.113532: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.114156: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.114808: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.115448: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.116096: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.116781: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.117459: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.118120: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20186 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:06:00.0, compute capability: 8.0
# 2023-05-16 19:01:47.119735: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.120399: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 20042 MB memory:  -> device: 1, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:07:00.0, compute capability: 8.0
# 2023-05-16 19:01:47.144806: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.145470: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 20042 MB memory:  -> device: 2, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:08:00.0, compute capability: 8.0
# 2023-05-16 19:01:47.147351: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.147885: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 20042 MB memory:  -> device: 3, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:09:00.0, compute capability: 8.0
# 2023-05-16 19:01:47.158580: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.159299: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 20042 MB memory:  -> device: 4, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:0a:00.0, compute capability: 8.0
# 2023-05-16 19:01:47.160724: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.161367: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:5 with 20042 MB memory:  -> device: 5, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:0b:00.0, compute capability: 8.0
# 2023-05-16 19:01:47.164567: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.165219: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:6 with 20042 MB memory:  -> device: 6, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:0c:00.0, compute capability: 8.0
# 2023-05-16 19:01:47.166353: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 19:01:47.166961: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:7 with 20186 MB memory:  -> device: 7, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:0d:00.0, compute capability: 8.0

# %%
hrnet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(32, 256, 256, 3)]  0           []
#
#  conv2d (Conv2D)                (32, 128, 128, 64)   1728        ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (32, 128, 128, 64)  256         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (32, 128, 128, 64)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (32, 128, 128, 64)   4096        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (32, 128, 128, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (32, 128, 128, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (32, 128, 128, 64)   36864       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (32, 128, 128, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (32, 128, 128, 64)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (32, 128, 128, 256)  16384       ['activation_2[0][0]']
#
#  conv2d_4 (Conv2D)              (32, 128, 128, 256)  16384       ['activation[0][0]']
#
#  batch_normalization_3 (BatchNo  (32, 128, 128, 256)  1024       ['conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (32, 128, 128, 256)  1024       ['conv2d_4[0][0]']
#  rmalization)
#
#  add (Add)                      (32, 128, 128, 256)  0           ['batch_normalization_3[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  activation_3 (Activation)      (32, 128, 128, 256)  0           ['add[0][0]']
#
#  conv2d_5 (Conv2D)              (32, 128, 128, 64)   16384       ['activation_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (32, 128, 128, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (32, 128, 128, 64)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (32, 128, 128, 64)   36864       ['activation_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (32, 128, 128, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (32, 128, 128, 64)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (32, 128, 128, 256)  16384       ['activation_5[0][0]']
#
#  batch_normalization_7 (BatchNo  (32, 128, 128, 256)  1024       ['conv2d_7[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (32, 128, 128, 256)  0           ['batch_normalization_7[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (32, 128, 128, 256)  0           ['add_1[0][0]']
#
#  conv2d_8 (Conv2D)              (32, 128, 128, 64)   16384       ['activation_6[0][0]']
#
#  batch_normalization_8 (BatchNo  (32, 128, 128, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (32, 128, 128, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (32, 128, 128, 64)   36864       ['activation_7[0][0]']
#
#  batch_normalization_9 (BatchNo  (32, 128, 128, 64)  256         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (32, 128, 128, 64)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (32, 128, 128, 256)  16384       ['activation_8[0][0]']
#
#  batch_normalization_10 (BatchN  (32, 128, 128, 256)  1024       ['conv2d_10[0][0]']
#  ormalization)
#
#  add_2 (Add)                    (32, 128, 128, 256)  0           ['batch_normalization_10[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (32, 128, 128, 256)  0           ['add_2[0][0]']
#
#  conv2d_11 (Conv2D)             (32, 128, 128, 64)   16384       ['activation_9[0][0]']
#
#  batch_normalization_11 (BatchN  (32, 128, 128, 64)  256         ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (32, 128, 128, 64)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (32, 128, 128, 64)   36864       ['activation_10[0][0]']
#
#  batch_normalization_12 (BatchN  (32, 128, 128, 64)  256         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (32, 128, 128, 64)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (32, 128, 128, 256)  16384       ['activation_11[0][0]']
#
#  batch_normalization_13 (BatchN  (32, 128, 128, 256)  1024       ['conv2d_13[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (32, 128, 128, 256)  0           ['batch_normalization_13[0][0]',
#                                                                   'activation_9[0][0]']
#
#  activation_12 (Activation)     (32, 128, 128, 256)  0           ['add_3[0][0]']
#
#  conv2d_15 (Conv2D)             (32, 64, 64, 64)     147456      ['activation_12[0][0]']
#
#  batch_normalization_15 (BatchN  (32, 64, 64, 64)    256         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (32, 64, 64, 64)     0           ['batch_normalization_15[0][0]']
#
#  conv2d_14 (Conv2D)             (32, 128, 128, 32)   73728       ['activation_12[0][0]']
#
#  conv2d_24 (Conv2D)             (32, 64, 64, 64)     36864       ['activation_14[0][0]']
#
#  batch_normalization_14 (BatchN  (32, 128, 128, 32)  128         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (32, 64, 64, 64)    256         ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (32, 128, 128, 32)   0           ['batch_normalization_14[0][0]']
#
#  activation_23 (Activation)     (32, 64, 64, 64)     0           ['batch_normalization_24[0][0]']
#
#  conv2d_16 (Conv2D)             (32, 128, 128, 32)   9216        ['activation_13[0][0]']
#
#  conv2d_25 (Conv2D)             (32, 64, 64, 64)     36864       ['activation_23[0][0]']
#
#  batch_normalization_16 (BatchN  (32, 128, 128, 32)  128         ['conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (32, 64, 64, 64)    256         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (32, 128, 128, 32)   0           ['batch_normalization_16[0][0]']
#
#  add_8 (Add)                    (32, 64, 64, 64)     0           ['batch_normalization_25[0][0]',
#                                                                   'activation_14[0][0]']
#
#  conv2d_17 (Conv2D)             (32, 128, 128, 32)   9216        ['activation_15[0][0]']
#
#  activation_24 (Activation)     (32, 64, 64, 64)     0           ['add_8[0][0]']
#
#  batch_normalization_17 (BatchN  (32, 128, 128, 32)  128         ['conv2d_17[0][0]']
#  ormalization)
#
#  conv2d_26 (Conv2D)             (32, 64, 64, 64)     36864       ['activation_24[0][0]']
#
#  add_4 (Add)                    (32, 128, 128, 32)   0           ['batch_normalization_17[0][0]',
#                                                                   'activation_13[0][0]']
#
#  batch_normalization_26 (BatchN  (32, 64, 64, 64)    256         ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (32, 128, 128, 32)   0           ['add_4[0][0]']
#
#  activation_25 (Activation)     (32, 64, 64, 64)     0           ['batch_normalization_26[0][0]']
#
#  conv2d_18 (Conv2D)             (32, 128, 128, 32)   9216        ['activation_16[0][0]']
#
#  conv2d_27 (Conv2D)             (32, 64, 64, 64)     36864       ['activation_25[0][0]']
#
#  batch_normalization_18 (BatchN  (32, 128, 128, 32)  128         ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_27 (BatchN  (32, 64, 64, 64)    256         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (32, 128, 128, 32)   0           ['batch_normalization_18[0][0]']
#
#  add_9 (Add)                    (32, 64, 64, 64)     0           ['batch_normalization_27[0][0]',
#                                                                   'activation_24[0][0]']
#
#  conv2d_19 (Conv2D)             (32, 128, 128, 32)   9216        ['activation_17[0][0]']
#
#  activation_26 (Activation)     (32, 64, 64, 64)     0           ['add_9[0][0]']
#
#  batch_normalization_19 (BatchN  (32, 128, 128, 32)  128         ['conv2d_19[0][0]']
#  ormalization)
#
#  conv2d_28 (Conv2D)             (32, 64, 64, 64)     36864       ['activation_26[0][0]']
#
#  add_5 (Add)                    (32, 128, 128, 32)   0           ['batch_normalization_19[0][0]',
#                                                                   'activation_16[0][0]']
#
#  batch_normalization_28 (BatchN  (32, 64, 64, 64)    256         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (32, 128, 128, 32)   0           ['add_5[0][0]']
#
#  activation_27 (Activation)     (32, 64, 64, 64)     0           ['batch_normalization_28[0][0]']
#
#  conv2d_20 (Conv2D)             (32, 128, 128, 32)   9216        ['activation_18[0][0]']
#
#  conv2d_29 (Conv2D)             (32, 64, 64, 64)     36864       ['activation_27[0][0]']
#
#  batch_normalization_20 (BatchN  (32, 128, 128, 32)  128         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (32, 64, 64, 64)    256         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (32, 128, 128, 32)   0           ['batch_normalization_20[0][0]']
#
#  add_10 (Add)                   (32, 64, 64, 64)     0           ['batch_normalization_29[0][0]',
#                                                                   'activation_26[0][0]']
#
#  conv2d_21 (Conv2D)             (32, 128, 128, 32)   9216        ['activation_19[0][0]']
#
#  activation_28 (Activation)     (32, 64, 64, 64)     0           ['add_10[0][0]']
#
#  batch_normalization_21 (BatchN  (32, 128, 128, 32)  128         ['conv2d_21[0][0]']
#  ormalization)
#
#  conv2d_30 (Conv2D)             (32, 64, 64, 64)     36864       ['activation_28[0][0]']
#
#  add_6 (Add)                    (32, 128, 128, 32)   0           ['batch_normalization_21[0][0]',
#                                                                   'activation_18[0][0]']
#
#  batch_normalization_30 (BatchN  (32, 64, 64, 64)    256         ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (32, 128, 128, 32)   0           ['add_6[0][0]']
#
#  activation_29 (Activation)     (32, 64, 64, 64)     0           ['batch_normalization_30[0][0]']
#
#  conv2d_22 (Conv2D)             (32, 128, 128, 32)   9216        ['activation_20[0][0]']
#
#  conv2d_31 (Conv2D)             (32, 64, 64, 64)     36864       ['activation_29[0][0]']
#
#  batch_normalization_22 (BatchN  (32, 128, 128, 32)  128         ['conv2d_22[0][0]']
#  ormalization)
#
#  batch_normalization_31 (BatchN  (32, 64, 64, 64)    256         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (32, 128, 128, 32)   0           ['batch_normalization_22[0][0]']
#
#  add_11 (Add)                   (32, 64, 64, 64)     0           ['batch_normalization_31[0][0]',
#                                                                   'activation_28[0][0]']
#
#  conv2d_23 (Conv2D)             (32, 128, 128, 32)   9216        ['activation_21[0][0]']
#
#  activation_30 (Activation)     (32, 64, 64, 64)     0           ['add_11[0][0]']
#
#  batch_normalization_23 (BatchN  (32, 128, 128, 32)  128         ['conv2d_23[0][0]']
#  ormalization)
#
#  conv2d_32 (Conv2D)             (32, 64, 64, 32)     2048        ['activation_30[0][0]']
#
#  add_7 (Add)                    (32, 128, 128, 32)   0           ['batch_normalization_23[0][0]',
#                                                                   'activation_20[0][0]']
#
#  batch_normalization_32 (BatchN  (32, 64, 64, 32)    128         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (32, 128, 128, 32)   0           ['add_7[0][0]']
#
#  up_sampling2d (UpSampling2D)   (32, 128, 128, 32)   0           ['batch_normalization_32[0][0]']
#
#  add_12 (Add)                   (32, 128, 128, 32)   0           ['activation_22[0][0]',
#                                                                   'up_sampling2d[0][0]']
#
#  conv2d_33 (Conv2D)             (32, 64, 64, 64)     18432       ['activation_22[0][0]']
#
#  conv2d_34 (Conv2D)             (32, 128, 128, 32)   9216        ['add_12[0][0]']
#
#  batch_normalization_33 (BatchN  (32, 64, 64, 64)    256         ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_34 (BatchN  (32, 128, 128, 32)  128         ['conv2d_34[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (32, 64, 64, 64)     0           ['batch_normalization_33[0][0]',
#                                                                   'activation_30[0][0]']
#
#  activation_31 (Activation)     (32, 128, 128, 32)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_36 (Conv2D)             (32, 32, 32, 128)    73728       ['add_13[0][0]']
#
#  conv2d_37 (Conv2D)             (32, 128, 128, 32)   9216        ['activation_31[0][0]']
#
#  conv2d_35 (Conv2D)             (32, 64, 64, 64)     36864       ['add_13[0][0]']
#
#  batch_normalization_36 (BatchN  (32, 32, 32, 128)   512         ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (32, 128, 128, 32)  128         ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_35 (BatchN  (32, 64, 64, 64)    256         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (32, 32, 32, 128)    0           ['batch_normalization_36[0][0]']
#
#  activation_34 (Activation)     (32, 128, 128, 32)   0           ['batch_normalization_37[0][0]']
#
#  activation_32 (Activation)     (32, 64, 64, 64)     0           ['batch_normalization_35[0][0]']
#
#  conv2d_53 (Conv2D)             (32, 32, 32, 128)    147456      ['activation_33[0][0]']
#
#  conv2d_38 (Conv2D)             (32, 128, 128, 32)   9216        ['activation_34[0][0]']
#
#  conv2d_45 (Conv2D)             (32, 64, 64, 64)     36864       ['activation_32[0][0]']
#
#  batch_normalization_53 (BatchN  (32, 32, 32, 128)   512         ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (32, 128, 128, 32)  128         ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_45 (BatchN  (32, 64, 64, 64)    256         ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (32, 32, 32, 128)    0           ['batch_normalization_53[0][0]']
#
#  add_14 (Add)                   (32, 128, 128, 32)   0           ['batch_normalization_38[0][0]',
#                                                                   'activation_31[0][0]']
#
#  activation_42 (Activation)     (32, 64, 64, 64)     0           ['batch_normalization_45[0][0]']
#
#  conv2d_54 (Conv2D)             (32, 32, 32, 128)    147456      ['activation_50[0][0]']
#
#  activation_35 (Activation)     (32, 128, 128, 32)   0           ['add_14[0][0]']
#
#  conv2d_46 (Conv2D)             (32, 64, 64, 64)     36864       ['activation_42[0][0]']
#
#  batch_normalization_54 (BatchN  (32, 32, 32, 128)   512         ['conv2d_54[0][0]']
#  ormalization)
#
#  conv2d_39 (Conv2D)             (32, 128, 128, 32)   9216        ['activation_35[0][0]']
#
#  batch_normalization_46 (BatchN  (32, 64, 64, 64)    256         ['conv2d_46[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (32, 32, 32, 128)    0           ['batch_normalization_54[0][0]',
#                                                                   'activation_33[0][0]']
#
#  batch_normalization_39 (BatchN  (32, 128, 128, 32)  128         ['conv2d_39[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (32, 64, 64, 64)     0           ['batch_normalization_46[0][0]',
#                                                                   'activation_32[0][0]']
#
#  activation_51 (Activation)     (32, 32, 32, 128)    0           ['add_22[0][0]']
#
#  activation_36 (Activation)     (32, 128, 128, 32)   0           ['batch_normalization_39[0][0]']
#
#  activation_43 (Activation)     (32, 64, 64, 64)     0           ['add_18[0][0]']
#
#  conv2d_55 (Conv2D)             (32, 32, 32, 128)    147456      ['activation_51[0][0]']
#
#  conv2d_40 (Conv2D)             (32, 128, 128, 32)   9216        ['activation_36[0][0]']
#
#  conv2d_47 (Conv2D)             (32, 64, 64, 64)     36864       ['activation_43[0][0]']
#
#  batch_normalization_55 (BatchN  (32, 32, 32, 128)   512         ['conv2d_55[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (32, 128, 128, 32)  128         ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (32, 64, 64, 64)    256         ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (32, 32, 32, 128)    0           ['batch_normalization_55[0][0]']
#
#  add_15 (Add)                   (32, 128, 128, 32)   0           ['batch_normalization_40[0][0]',
#                                                                   'activation_35[0][0]']
#
#  activation_44 (Activation)     (32, 64, 64, 64)     0           ['batch_normalization_47[0][0]']
#
#  conv2d_56 (Conv2D)             (32, 32, 32, 128)    147456      ['activation_52[0][0]']
#
#  activation_37 (Activation)     (32, 128, 128, 32)   0           ['add_15[0][0]']
#
#  conv2d_48 (Conv2D)             (32, 64, 64, 64)     36864       ['activation_44[0][0]']
#
#  batch_normalization_56 (BatchN  (32, 32, 32, 128)   512         ['conv2d_56[0][0]']
#  ormalization)
#
#  conv2d_41 (Conv2D)             (32, 128, 128, 32)   9216        ['activation_37[0][0]']
#
#  batch_normalization_48 (BatchN  (32, 64, 64, 64)    256         ['conv2d_48[0][0]']
#  ormalization)
#
#  add_23 (Add)                   (32, 32, 32, 128)    0           ['batch_normalization_56[0][0]',
#                                                                   'activation_51[0][0]']
#
#  batch_normalization_41 (BatchN  (32, 128, 128, 32)  128         ['conv2d_41[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (32, 64, 64, 64)     0           ['batch_normalization_48[0][0]',
#                                                                   'activation_43[0][0]']
#
#  activation_53 (Activation)     (32, 32, 32, 128)    0           ['add_23[0][0]']
#
#  activation_38 (Activation)     (32, 128, 128, 32)   0           ['batch_normalization_41[0][0]']
#
#  activation_45 (Activation)     (32, 64, 64, 64)     0           ['add_19[0][0]']
#
#  conv2d_57 (Conv2D)             (32, 32, 32, 128)    147456      ['activation_53[0][0]']
#
#  conv2d_42 (Conv2D)             (32, 128, 128, 32)   9216        ['activation_38[0][0]']
#
#  conv2d_49 (Conv2D)             (32, 64, 64, 64)     36864       ['activation_45[0][0]']
#
#  batch_normalization_57 (BatchN  (32, 32, 32, 128)   512         ['conv2d_57[0][0]']
#  ormalization)
#
#  batch_normalization_42 (BatchN  (32, 128, 128, 32)  128         ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (32, 64, 64, 64)    256         ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (32, 32, 32, 128)    0           ['batch_normalization_57[0][0]']
#
#  add_16 (Add)                   (32, 128, 128, 32)   0           ['batch_normalization_42[0][0]',
#                                                                   'activation_37[0][0]']
#
#  activation_46 (Activation)     (32, 64, 64, 64)     0           ['batch_normalization_49[0][0]']
#
#  conv2d_58 (Conv2D)             (32, 32, 32, 128)    147456      ['activation_54[0][0]']
#
#  activation_39 (Activation)     (32, 128, 128, 32)   0           ['add_16[0][0]']
#
#  conv2d_50 (Conv2D)             (32, 64, 64, 64)     36864       ['activation_46[0][0]']
#
#  batch_normalization_58 (BatchN  (32, 32, 32, 128)   512         ['conv2d_58[0][0]']
#  ormalization)
#
#  conv2d_43 (Conv2D)             (32, 128, 128, 32)   9216        ['activation_39[0][0]']
#
#  batch_normalization_50 (BatchN  (32, 64, 64, 64)    256         ['conv2d_50[0][0]']
#  ormalization)
#
#  add_24 (Add)                   (32, 32, 32, 128)    0           ['batch_normalization_58[0][0]',
#                                                                   'activation_53[0][0]']
#
#  batch_normalization_43 (BatchN  (32, 128, 128, 32)  128         ['conv2d_43[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (32, 64, 64, 64)     0           ['batch_normalization_50[0][0]',
#                                                                   'activation_45[0][0]']
#
#  activation_55 (Activation)     (32, 32, 32, 128)    0           ['add_24[0][0]']
#
#  activation_40 (Activation)     (32, 128, 128, 32)   0           ['batch_normalization_43[0][0]']
#
#  activation_47 (Activation)     (32, 64, 64, 64)     0           ['add_20[0][0]']
#
#  conv2d_59 (Conv2D)             (32, 32, 32, 128)    147456      ['activation_55[0][0]']
#
#  conv2d_44 (Conv2D)             (32, 128, 128, 32)   9216        ['activation_40[0][0]']
#
#  conv2d_51 (Conv2D)             (32, 64, 64, 64)     36864       ['activation_47[0][0]']
#
#  batch_normalization_59 (BatchN  (32, 32, 32, 128)   512         ['conv2d_59[0][0]']
#  ormalization)
#
#  batch_normalization_44 (BatchN  (32, 128, 128, 32)  128         ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_51 (BatchN  (32, 64, 64, 64)    256         ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_56 (Activation)     (32, 32, 32, 128)    0           ['batch_normalization_59[0][0]']
#
#  add_17 (Add)                   (32, 128, 128, 32)   0           ['batch_normalization_44[0][0]',
#                                                                   'activation_39[0][0]']
#
#  activation_48 (Activation)     (32, 64, 64, 64)     0           ['batch_normalization_51[0][0]']
#
# ...
#  activation_66 (Activation)     (32, 128, 128, 32)   0           ['add_30[0][0]']
#
#  activation_75 (Activation)     (32, 64, 64, 64)     0           ['batch_normalization_84[0][0]']
#
#  activation_83 (Activation)     (32, 32, 32, 128)    0           ['batch_normalization_92[0][0]']
#
#  activation_91 (Activation)     (32, 16, 16, 256)    0           ['batch_normalization_100[0][0]']
#
#  conv2d_76 (Conv2D)             (32, 128, 128, 32)   9216        ['activation_66[0][0]']
#
#  conv2d_85 (Conv2D)             (32, 64, 64, 64)     36864       ['activation_75[0][0]']
#
#  conv2d_93 (Conv2D)             (32, 32, 32, 128)    147456      ['activation_83[0][0]']
#
#  conv2d_101 (Conv2D)            (32, 16, 16, 256)    589824      ['activation_91[0][0]']
#
#  batch_normalization_76 (BatchN  (32, 128, 128, 32)  128         ['conv2d_76[0][0]']
#  ormalization)
#
#  batch_normalization_85 (BatchN  (32, 64, 64, 64)    256         ['conv2d_85[0][0]']
#  ormalization)
#
#  batch_normalization_93 (BatchN  (32, 32, 32, 128)   512         ['conv2d_93[0][0]']
#  ormalization)
#
#  batch_normalization_101 (Batch  (32, 16, 16, 256)   1024        ['conv2d_101[0][0]']
#  Normalization)
#
#  activation_67 (Activation)     (32, 128, 128, 32)   0           ['batch_normalization_76[0][0]']
#
#  add_35 (Add)                   (32, 64, 64, 64)     0           ['batch_normalization_85[0][0]',
#                                                                   'activation_74[0][0]']
#
#  add_39 (Add)                   (32, 32, 32, 128)    0           ['batch_normalization_93[0][0]',
#                                                                   'activation_82[0][0]']
#
#  add_43 (Add)                   (32, 16, 16, 256)    0           ['batch_normalization_101[0][0]',
#                                                                   'activation_90[0][0]']
#
#  conv2d_77 (Conv2D)             (32, 128, 128, 32)   9216        ['activation_67[0][0]']
#
#  activation_76 (Activation)     (32, 64, 64, 64)     0           ['add_35[0][0]']
#
#  activation_84 (Activation)     (32, 32, 32, 128)    0           ['add_39[0][0]']
#
#  activation_92 (Activation)     (32, 16, 16, 256)    0           ['add_43[0][0]']
#
#  batch_normalization_77 (BatchN  (32, 128, 128, 32)  128         ['conv2d_77[0][0]']
#  ormalization)
#
#  conv2d_86 (Conv2D)             (32, 64, 64, 64)     36864       ['activation_76[0][0]']
#
#  conv2d_94 (Conv2D)             (32, 32, 32, 128)    147456      ['activation_84[0][0]']
#
#  conv2d_102 (Conv2D)            (32, 16, 16, 256)    589824      ['activation_92[0][0]']
#
#  add_31 (Add)                   (32, 128, 128, 32)   0           ['batch_normalization_77[0][0]',
#                                                                   'activation_66[0][0]']
#
#  batch_normalization_86 (BatchN  (32, 64, 64, 64)    256         ['conv2d_86[0][0]']
#  ormalization)
#
#  batch_normalization_94 (BatchN  (32, 32, 32, 128)   512         ['conv2d_94[0][0]']
#  ormalization)
#
#  batch_normalization_102 (Batch  (32, 16, 16, 256)   1024        ['conv2d_102[0][0]']
#  Normalization)
#
#  activation_68 (Activation)     (32, 128, 128, 32)   0           ['add_31[0][0]']
#
#  activation_77 (Activation)     (32, 64, 64, 64)     0           ['batch_normalization_86[0][0]']
#
#  activation_85 (Activation)     (32, 32, 32, 128)    0           ['batch_normalization_94[0][0]']
#
#  activation_93 (Activation)     (32, 16, 16, 256)    0           ['batch_normalization_102[0][0]']
#
#  conv2d_78 (Conv2D)             (32, 128, 128, 32)   9216        ['activation_68[0][0]']
#
#  conv2d_87 (Conv2D)             (32, 64, 64, 64)     36864       ['activation_77[0][0]']
#
#  conv2d_95 (Conv2D)             (32, 32, 32, 128)    147456      ['activation_85[0][0]']
#
#  conv2d_103 (Conv2D)            (32, 16, 16, 256)    589824      ['activation_93[0][0]']
#
#  batch_normalization_78 (BatchN  (32, 128, 128, 32)  128         ['conv2d_78[0][0]']
#  ormalization)
#
#  batch_normalization_87 (BatchN  (32, 64, 64, 64)    256         ['conv2d_87[0][0]']
#  ormalization)
#
#  batch_normalization_95 (BatchN  (32, 32, 32, 128)   512         ['conv2d_95[0][0]']
#  ormalization)
#
#  batch_normalization_103 (Batch  (32, 16, 16, 256)   1024        ['conv2d_103[0][0]']
#  Normalization)
#
#  activation_69 (Activation)     (32, 128, 128, 32)   0           ['batch_normalization_78[0][0]']
#
#  add_36 (Add)                   (32, 64, 64, 64)     0           ['batch_normalization_87[0][0]',
#                                                                   'activation_76[0][0]']
#
#  add_40 (Add)                   (32, 32, 32, 128)    0           ['batch_normalization_95[0][0]',
#                                                                   'activation_84[0][0]']
#
#  add_44 (Add)                   (32, 16, 16, 256)    0           ['batch_normalization_103[0][0]',
#                                                                   'activation_92[0][0]']
#
#  conv2d_79 (Conv2D)             (32, 128, 128, 32)   9216        ['activation_69[0][0]']
#
#  activation_78 (Activation)     (32, 64, 64, 64)     0           ['add_36[0][0]']
#
#  activation_86 (Activation)     (32, 32, 32, 128)    0           ['add_40[0][0]']
#
#  activation_94 (Activation)     (32, 16, 16, 256)    0           ['add_44[0][0]']
#
#  batch_normalization_79 (BatchN  (32, 128, 128, 32)  128         ['conv2d_79[0][0]']
#  ormalization)
#
#  conv2d_104 (Conv2D)            (32, 64, 64, 32)     2048        ['activation_78[0][0]']
#
#  conv2d_105 (Conv2D)            (32, 32, 32, 32)     4096        ['activation_86[0][0]']
#
#  conv2d_106 (Conv2D)            (32, 16, 16, 32)     8192        ['activation_94[0][0]']
#
#  add_32 (Add)                   (32, 128, 128, 32)   0           ['batch_normalization_79[0][0]',
#                                                                   'activation_68[0][0]']
#
#  batch_normalization_104 (Batch  (32, 64, 64, 32)    128         ['conv2d_104[0][0]']
#  Normalization)
#
#  batch_normalization_105 (Batch  (32, 32, 32, 32)    128         ['conv2d_105[0][0]']
#  Normalization)
#
#  batch_normalization_106 (Batch  (32, 16, 16, 32)    128         ['conv2d_106[0][0]']
#  Normalization)
#
#  activation_70 (Activation)     (32, 128, 128, 32)   0           ['add_32[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (32, 128, 128, 32)  0           ['batch_normalization_104[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (32, 128, 128, 32)  0           ['batch_normalization_105[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (32, 128, 128, 32)  0           ['batch_normalization_106[0][0]']
#
#  concatenate (Concatenate)      (32, 128, 128, 128)  0           ['activation_70[0][0]',
#                                                                   'up_sampling2d_4[0][0]',
#                                                                   'up_sampling2d_5[0][0]',
#                                                                   'up_sampling2d_6[0][0]']
#
#  up_sampling2d_7 (UpSampling2D)  (32, 256, 256, 128)  0          ['concatenate[0][0]']
#
#  conv2d_107 (Conv2D)            (32, 256, 256, 2)    256         ['up_sampling2d_7[0][0]']
#
#  batch_normalization_107 (Batch  (32, 256, 256, 2)   8           ['conv2d_107[0][0]']
#  Normalization)
#
#  Classification (Activation)    (32, 256, 256, 2)    0           ['batch_normalization_107[0][0]']
#
# ==================================================================================================
# Total params: 9,524,168
# Trainable params: 9,504,708
# Non-trainable params: 19,460
# __________________________________________________________________________________________________
